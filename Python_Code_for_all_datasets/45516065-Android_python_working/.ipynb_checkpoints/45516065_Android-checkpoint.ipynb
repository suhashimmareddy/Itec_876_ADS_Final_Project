# %%
import bs4
from urllib.request import urlopen as ureq
from bs4 import BeautifulSoup as Soup

# %%
def Extract(raj):
    f = open("Android.txt", "a+", encoding = "utf-8")
    for c in raj:
        question_summary = c.a.text
        tags = []
        question_tags = c.findAll("div", {"class":"tags"})
        tagies = question_tags[0].findAll("a")
        for i in range(0,len(tagies)):
            tags.append(tagies[i].text)
            f.write("_label_"+tags[i]+" ")
        f.write(question_summary+"\n")
    f.close()

# %%
def data(i):
    my_url = "https://android.stackexchange.com/questions?tab=newest&page="+str(i)+"&pagesize=50"
    uclient = ureq(my_url) # opens up the connection grabs the web page and stores in a variable
    page_html = uclient.read()
    uclient.close()
    page_soup = Soup(page_html, "html.parser")
    containers = page_soup.findAll("div", {"class":"question-summary"})
    raj = containers[0:50]
    Extract(raj)

# %%
for i in range(1,200):
    data(i)

# %%
for i in range(200, 400):
    data(i)

# %%
for i in range(400, 600):
    data(i)

# %%
for i in range(600, 800):
    data(i)

# %%
for i in range(805,1004):
    data(i)

# %%
import pandas as pd
data = pd.read_csv('android.txt',error_bad_lines=False,header = None)
data
# Out:
# b'Skipping line 82: expected 1 fields, saw 2\nSkipping line 95: expected 1 fields, saw 2\nSkipping line 115: expected 1 fields, saw 3\nSkipping line 133: expected 1 fields, saw 2\nSkipping line 138: expected 1 fields, saw 2\nSkipping line 148: expected 1 fields, saw 2\nSkipping line 173: expected 1 fields, saw 2\nSkipping line 181: expected 1 fields, saw 3\nSkipping line 191: expected 1 fields, saw 3\nSkipping line 199: expected 1 fields, saw 2\nSkipping line 208: expected 1 fields, saw 2\nSkipping line 210: expected 1 fields, saw 3\nSkipping line 214: expected 1 fields, saw 2\nSkipping line 216: expected 1 fields, saw 2\nSkipping line 217: expected 1 fields, saw 2\nSkipping line 225: expected 1 fields, saw 2\nSkipping line 226: expected 1 fields, saw 2\nSkipping line 228: expected 1 fields, saw 2\nSkipping line 249: expected 1 fields, saw 2\nSkipping line 251: expected 1 fields, saw 2\nSkipping line 263: expected 1 fields, saw 2\nSkipping line 274: expected 1 fields, saw 2\nSkipping line 280: expected 1 fields, saw 2\nSkipping line 301: expected 1 fields, saw 2\nSkipping line 311: expected 1 fields, saw 2\nSkipping line 325: expected 1 fields, saw 4\nSkipping line 346: expected 1 fields, saw 2\nSkipping line 446: expected 1 fields, saw 3\nSkipping line 496: expected 1 fields, saw 2\nSkipping line 561: expected 1 fields, saw 3\nSkipping line 580: expected 1 fields, saw 2\nSkipping line 601: expected 1 fields, saw 2\nSkipping line 617: expected 1 fields, saw 2\nSkipping line 669: expected 1 fields, saw 2\nSkipping line 675: expected 1 fields, saw 2\nSkipping line 683: expected 1 fields, saw 2\nSkipping line 685: expected 1 fields, saw 2\nSkipping line 703: expected 1 fields, saw 2\nSkipping line 712: expected 1 fields, saw 2\nSkipping line 713: expected 1 fields, saw 2\nSkipping line 734: expected 1 fields, saw 2\nSkipping line 737: expected 1 fields, saw 3\nSkipping line 757: expected 1 fields, saw 2\nSkipping line 760: expected 1 fields, saw 2\nSkipping line 761: expected 1 fields, saw 2\nSkipping line 769: expected 1 fields, saw 2\nSkipping line 779: expected 1 fields, saw 2\nSkipping line 846: expected 1 fields, saw 2\nSkipping line 847: expected 1 fields, saw 2\nSkipping line 854: expected 1 fields, saw 4\nSkipping line 888: expected 1 fields, saw 2\nSkipping line 891: expected 1 fields, saw 2\nSkipping line 896: expected 1 fields, saw 2\nSkipping line 899: expected 1 fields, saw 2\nSkipping line 928: expected 1 fields, saw 2\nSkipping line 938: expected 1 fields, saw 2\nSkipping line 940: expected 1 fields, saw 2\nSkipping line 967: expected 1 fields, saw 2\nSkipping line 972: expected 1 fields, saw 2\nSkipping line 1037: expected 1 fields, saw 2\nSkipping line 1039: expected 1 fields, saw 2\nSkipping line 1046: expected 1 fields, saw 2\nSkipping line 1049: expected 1 fields, saw 2\nSkipping line 1074: expected 1 fields, saw 2\nSkipping line 1082: expected 1 fields, saw 2\nSkipping line 1084: expected 1 fields, saw 2\nSkipping line 1088: expected 1 fields, saw 2\nSkipping line 1111: expected 1 fields, saw 2\nSkipping line 1126: expected 1 fields, saw 2\nSkipping line 1127: expected 1 fields, saw 2\nSkipping line 1169: expected 1 fields, saw 3\nSkipping line 1170: expected 1 fields, saw 3\nSkipping line 1190: expected 1 fields, saw 2\nSkipping line 1213: expected 1 fields, saw 2\nSkipping line 1218: expected 1 fields, saw 2\nSkipping line 1229: expected 1 fields, saw 3\nSkipping line 1236: expected 1 fields, saw 2\nSkipping line 1240: expected 1 fields, saw 2\nSkipping line 1257: expected 1 fields, saw 2\nSkipping line 1261: expected 1 fields, saw 2\nSkipping line 1275: expected 1 fields, saw 2\nSkipping line 1305: expected 1 fields, saw 2\nSkipping line 1343: expected 1 fields, saw 3\nSkipping line 1353: expected 1 fields, saw 2\nSkipping line 1388: expected 1 fields, saw 3\nSkipping line 1396: expected 1 fields, saw 2\nSkipping line 1399: expected 1 fields, saw 2\nSkipping line 1409: expected 1 fields, saw 2\nSkipping li ...
#                                                        0
# 0      _label_android-sdk Saving login information fo...
# 1      _label_chrome-for-android _label_browser _labe...
# 2      _label_android-sdk _label_intents How to run a...
# 3      _label_video _label_youtube _label_video-strea...
# 4      _label_wi-fi Random rebooting issues after the...
# 5      _label_android-sdk Android 3.5.1 Gradle Sync B...
# 6      _label_termux ssh to termux server disconnects...
# 7      _label_9.0-pie _label_android-one How to disab...
# 8      _label_5.0-lollipop _label_recovery-mode _labe...
# 9      _label_applications _label_instagram Why won't...
# 10     _label_device-firmware Where to download offic...
# 11     _label_whatsapp-messenger _label_automation _l...
# 12     _label_file-system I don't know how these file...
# 13     _label_google _label_privacy Macro for deletin...
# 14     _label_9.0-pie _label_chinese Alcatel S1 - add...
# 15     _label_applications _label_java Noob Question:...
# 16     _label_whatsapp-messenger _label_instagram Pad...
# 17     _label_mac-os-x _label_certificates Why can't ...
# 18     _label_android-sdk _label_java _label_sqlite s...
# 19     _label_samsung _label_sms _label_samsung-galax...
# 20     _label_xposed-framework _label_safety-net _lab...
# 21     _label_wi-fi _label_linux _label_networking _l...
# 22     _label_mac-os-x Android studio build speedness...
# 23     _label_applications two google email acccounts...
# 24     _label_rom-flashing _label_bootloader _label_x...
# 25     _label_broken-screen Do I have to repair a cra...
# 26     _label_camera Managing multiple physical camer...
# 27      _label_rom-flashing system.new.dat vs system.img
# 28     _label_device-migration Facebook Messenger dat...
# 29     _label_hardware Are quantum RNGs on an Android...
# ...                                                  ...
# 46788  _label_samsung-galaxy-tab _label_wifi-tetherin...
# 46789  _label_buttons _label_motorola-droid-pro How t...
# 46790  _label_wi-fi _label_hardware What Android phon...
# 46791  _label_samsung-galaxy-s _label_screen _label_o...
# 46792  _label_email Email app displays messages in “S...
# 46793  _label_2.2-froyo _label_samsung-galaxy-s _labe...
# 46794  _label_j2me How can I install .jar files on my...
# 46795  _label_samsung-galaxy-s _label_time-zones How ...
# 46796  _label_security _label_privacy I have sold my ...
# 46797  _label_reboot _label_samsung-europa Phone keep...
# 46798  _label_skype Is there a Skype compatible clien...
# 46799  _label_2.2-froyo _label_screen-timeout _label_...
# 46800  _label_home-screen How to remove home-screens ...
# 46801  _label_2.2-froyo _label_widgets What does the ...
# 46802  _label_2.1-eclair _label_htc-sense _label_droi...
# 46803  _label_audio _label_silent-mode Accidentally t...
# 46804  _label_email _label_samsung-continuum Set defa...
# 46805  _label_keyboard _label_input-methods How can I...
# 46806  _label_2.1-eclair _label_security _label_encry...
# 46807  _label_motorola-droid-pro _label_sim-unlocking...
# 46808  _label_battery-life _label_htc-desire-hd Batte...
# 46809  _label_applications _label_root-access How can...
# 46810  _label_screen _label_nexus-one _label_wakelock...
# 46811  _label_security _label_permissions _label_priv...
# 46812  _label_bluetooth _label_keyboard Can I emulate...
# 46813  _label_google-play-store _label_rooting How do...
# 46814  _label_bluetooth _label_tasker _label_locale C...
# 46815  _label_htc-desire _label_htc-sense _label_unin...
# 46816     _label_contacts How to add contact from email?
# 46817  _label_exchange _label_htc-droid-incredible _l...
#
# [46818 rows x 1 columns]

# %%
label_data = data[0].str.count("_label_")
print('Total label count is:',data[0].str.count("_label_").sum())
# Out:
# Total label count is: 113006

# %%
import matplotlib.pyplot as plt
plt.hist(label_data, alpha=0.5, color = 'green', label='labels')
plt.xlabel('Number of labels')
plt.ylabel('Count of labels')
plt.legend(loc='upper right')
plt.show()
